# %% [markdown]
# # Objective
#
# 1. Build an RNN model for IMDB dataset
# 2. Adjust the parameters for better accuracy, such as number of layers, number of nodes in each layer, optimizer, learning rate, etc

# %% [markdown]
# # Prepare Environment

# %%
# %env KERAS_BACKEND=tensorflow
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
# Out:
# env: KERAS_BACKEND=tensorflow

# %% [markdown]
# # Prepare Data
# 1. Load data

# %%
from keras.datasets import imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# 2. Pad sequences
#     - Make all the reviews in the same length (100 words).
#     - If the review is too long, strip it; otherwise, pad zeros.

# %%
from keras.preprocessing import sequence
x_train = sequence.pad_sequences(x_train, maxlen=100)
x_test = sequence.pad_sequences(x_test, maxlen=100)

# %% [markdown]
# # Build RNN

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, GRU

def rnn(embed_dim=128, lstm=True, units=150, loss='binary_crossentropy', optimizer='adam', batch_size=32, epochs=15):
    model = Sequential()
    model.add(Embedding(10000, embed_dim))
    if lstm:
        model.add(LSTM(units))
    else:
        model.add(GRU(units))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])
    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)
    train_accuracy = model.evaluate(x_train, y_train)[1]
    test_accuracy = model.evaluate(x_test, y_test)[1]
    return (train_accuracy, test_accuracy)

# %% [markdown]
# ### Default setting from class
#     - Embedding the 10000 dimensional input to 128 dimensions
#     - Add an LSTM layer with 150 cells
#     - Loss function: binary crossentropy
#     - Optimizer: adam
#     - Batch size: 32
#     - Epochs: 15
#     - Results: (0.9962, 0.82784)

# %%
print('default setting:', rnn())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 128)         1280000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 150)               167400
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 25000/25000 [==============================] - 97s 4ms/step - loss: 0.4194 - acc: 0.8060
# Epoch 2/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2688 - acc: 0.8913
# Epoch 3/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.1931 - acc: 0.9266
# Epoch 4/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.1370 - acc: 0.9493
# Epoch 5/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0962 - acc: 0.9656
# Epoch 6/15
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.0705 - acc: 0.9758
# Epoch 7/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0517 - acc: 0.9824
# Epoch 8/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0399 - acc: 0.9876
# Epoch 9/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0296 - acc: 0.9902
# Epoch 10/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0292 - acc: 0.9911
# Epoch 11/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0291 - acc: 0.9913
# Epoch 12/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0185 - acc: 0.9940
# Epoch 13/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0248 - acc: 0.9920
# Epoch 14/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0105 - acc: 0.9968
# Epoch 15/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0100 - acc: 0.9971
# 25000/25000 [==============================] - 20s 806us/step
# 25000/25000 [==============================] - 20s 789us/step
# default setting: (0.9962, 0.82784)

# %% [markdown]
# # Tune Parameters
# 1. Number of epochs
#     - LSTM is very slow. Examine how many epochs are enough for acceptable results.
#     - Results
#         * epochs = 1 : (0.90556, 0.84448)
#         * epochs = 2 : (0.93988, 0.84452)
#         * epochs = 3 : (0.96588, 0.84432)
#         * epochs = 5 : (0.961, 0.81728)
#         * epochs = 10 : (0.99292, 0.8192)
#         * epochs = 15 : (0.99856, 0.833)
#         * epochs = 20 : (0.9966, 0.82776)
#     - Surprisingly, the accuracy was quite good for 1 epoch and reaches the best at 2 epochs. More epochs increase the accuracy of training data but not necessarily help the accuracy on testing data.

# %%
for epochs in [1, 2, 3, 5, 10, 15, 20]:
    print('epochs =', epochs, ':', rnn(epochs=epochs))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 128)         1280000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 150)               167400
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.4213 - acc: 0.8039
# 25000/25000 [==============================] - 20s 808us/step
# 25000/25000 [==============================] - 20s 801us/step
# epochs = 1 : (0.90556, 0.84448)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, None, 128)         1280000
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 150)               167400
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.4250 - acc: 0.8033
# Epoch 2/2
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.2689 - acc: 0.8946
# 25000/25000 [==============================] - 20s 815us/step
# 25000/25000 [==============================] - 20s 809us/step
# epochs = 2 : (0.93988, 0.84452)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 128)         1280000
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 150)               167400
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 97s 4ms/step - loss: 0.4289 - acc: 0.7993
# Epoch 2/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.2653 - acc: 0.8935
# Epoch 3/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.1882 - acc: 0.9285
# 25000/25000 [==============================] - 20s 818us/step
# 25000/25000 [==============================] - 20s 809us/step
# epochs = 3 : (0.96588, 0.84432)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, None, 128)         1280000
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 150)               167400
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 25000/25000 [==============================] - 97s 4ms/step - loss: 0.4130 - acc: 0.8098
# Epoch 2/5
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2635 - acc: 0.8942
# Epoch 3/5
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.1902 - acc: 0.9279
# Epoch 4/5
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.1406 - acc: 0.9478
# Epoch 5/5
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.1054 - acc: 0.9626
# 25000/25000 [==============================] - 20s 804us/step
# 25000/25000 [==============================] - 20s 791us/step
# epochs = 5 : (0.961, 0.81728)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, None, 128)         1280000
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 150)               167400
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.4212 - acc: 0.8062
# Epoch 2/10
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.2675 - acc: 0.8934
# Epoch 3/10
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.1949 - acc: 0.9252
# Epoch 4/10
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.1418 - acc: 0.9466
# Epoch 5/10
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.1071 - acc: 0.9624
# Epoch 6/10
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0802 - acc: 0.9730
# Epoch 7/10
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0609 - acc: 0.9790
# Epoch 8/10
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0495 - acc: 0.9834
# Epoch 9/10
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0354 - acc: 0.9888
# Epoch 10/10
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0322 - acc: 0.9895
# 25000/25000 [==============================] - 20s 802us/step
# 25000/25000 [==============================] - 20s 794us/step
# epochs = 10 : (0.99292, 0.8192)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, None, 128)         1280000
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 150)               167400
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.4441 - acc: 0.7864
# Epoch 2/15
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.2651 - acc: 0.8925
# Epoch 3/15
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.1850 - acc: 0.9289
# Epoch 4/15
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.1351 - acc: 0.9514
# Epoch 5/15
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.0909 - acc: 0.9693
# Epoch 6/15
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0693 - acc: 0.9764
# Epoch 7/15
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0516 - acc: 0.9832
# Epoch 8/15
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.0333 - acc: 0.9898
# Epoch 9/15
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0249 - acc: 0.9918
# Epoch 10/15
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.0227 - acc: 0.9932
# Epoch 11/15
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.0285 - acc: 0.9908
# Epoch 12/15
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.0192 - acc: 0.9942
# Epoch 13/15
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.0087 - acc: 0.9973
# Epoch 14/15
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.0137 - acc: 0.9960
# Epoch 15/15
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.0174 - acc: 0.9947
# 25000/25000 [==============================] - 20s 798us/step
# 25000/25000 [==============================] - 20s 789us/step
# epochs = 15 : (0.99856, 0.833)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, None, 128)         1280000
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 150)               167400
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.4216 - acc: 0.8017
# Epoch 2/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.2689 - acc: 0.8930
# Epoch 3/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.1918 - acc: 0.9262
# Epoch 4/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.1327 - acc: 0.9508
# Epoch 5/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.1003 - acc: 0.9645
# Epoch 6/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0694 - acc: 0.9770
# Epoch 7/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0531 - acc: 0.9825
# Epoch 8/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0477 - acc: 0.9847
# Epoch 9/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0293 - acc: 0.9906
# Epoch 10/20
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0260 - acc: 0.9916
# Epoch 11/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0285 - acc: 0.9909
# Epoch 12/20
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0163 - acc: 0.9952
# Epoch 13/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0169 - acc: 0.9947
# Epoch 14/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0225 - acc: 0.9936
# Epoch 15/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0083 - acc: 0.9976
# Epoch 16/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0075 - acc: 0.9977
# Epoch 17/20
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0138 - acc: 0.9961
# Epoch 18/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0089 - acc: 0.9972
# Epoch 19/20
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.0041 - acc: 0.9988
# Epoch 20/20
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0064 - acc: 0.9982
# 25000/25000 [==============================] - 21s 833us/step
# 25000/25000 [==============================] - 20s 798us/step
# epochs = 20 : (0.9966, 0.82776)

# %% [markdown]
# 2. Batch size
#     - Results
#         * batch_size = 10 : (0.97492, 0.85244), 12ms/step
#         * batch_size = 32 : (0.96528, 0.83848), 4ms/step
#         * batch_size = 100 : (0.96432, 0.83996), 1ms/step
#         * batch_size = 200 : (0.94932, 0.83884), 660us/step
#     - Smaller batch size gives more iterations to approach the optimized model. However, smaller batch also takes a lot more time.
#     -  If the amount of training data is enough, bigger batch size can reduce the training time and can still converge to acceptable accuracy.

# %%
for batch_size in [10, 32, 100, 200]:
    print('batch_size =', batch_size, ':', rnn(batch_size=batch_size, epochs=3))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, None, 128)         1280000
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 150)               167400
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 300s 12ms/step - loss: 0.4262 - acc: 0.8012
# Epoch 2/3
# 25000/25000 [==============================] - 298s 12ms/step - loss: 0.2570 - acc: 0.8962
# Epoch 3/3
# 25000/25000 [==============================] - 298s 12ms/step - loss: 0.1724 - acc: 0.9337
# 25000/25000 [==============================] - 20s 805us/step
# 25000/25000 [==============================] - 20s 792us/step
# batch_size = 10 : (0.97492, 0.85244)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.4309 - acc: 0.7981
# Epoch 2/3
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.2686 - acc: 0.8938
# Epoch 3/3
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.1858 - acc: 0.9278
# 25000/25000 [==============================] - 20s 806us/step
# 25000/25000 [==============================] - 20s 788us/step
# batch_size = 32 : (0.96528, 0.83848)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_11 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 31s 1ms/step - loss: 0.4367 - acc: 0.7911
# Epoch 2/3
# 25000/25000 [==============================] - 30s 1ms/step - loss: 0.2654 - acc: 0.8924
# Epoch 3/3
# 25000/25000 [==============================] - 30s 1ms/step - loss: 0.1975 - acc: 0.9244
# 25000/25000 [==============================] - 20s 809us/step
# 25000/25000 [==============================] - 20s 789us/step
# batch_size = 100 : (0.96432, 0.83996)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_12 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 17s 660us/step - loss: 0.4687 - acc: 0.7658
# Epoch 2/3
# 25000/25000 [==============================] - 15s 594us/step - loss: 0.2738 - acc: 0.8893
# Epoch 3/3
# 25000/25000 [==============================] - 15s 598us/step - loss: 0.2245 - acc: 0.9137
# 25000/25000 [==============================] - 20s 815us/step
# 25000/25000 [==============================] - 20s 794us/step
# batch_size = 200 : (0.94932, 0.83884)

# %% [markdown]
# 3. LSTM vs. GRU
#     - Results
#         * [LSTM] units = 10 : (0.96412, 0.85016), 4ms/step
#         * [GRU] units = 10 : (0.96884, 0.84808), 3ms/step
#         * [LSTM] units = 100 : (0.96372, 0.83808), 4ms/step
#         * [GRU] units = 100 : (0.97464, 0.84784), 3ms/step
#         * [LSTM] units = 150 : (0.94716, 0.8316), 4ms/step
#         * [GRU] units = 150 : (0.96908, 0.84532), 3ms/step
#         * [LSTM] units = 200 : (0.96444, 0.84276), 4ms/step
#         * [GRU] units = 200 : (0.97884, 0.84848), 3ms/step
#         * [LSTM] units = 300 : (0.95504, 0.83988), 4ms/step
#         * [GRU] units = 300 : (0.97624, 0.8484), 3ms/step
#     - As shown, GRU could save 25% of time compared to LSTM and still got about the same the accuracy.
#     - Increaing the number of units did not lead to better performance.
#     - Surprisingly, even though more parameters need to be adjusted when there are more units in LSTM or GRU, the training time does not increase apparently with the number of units. It indicated that most of the training time was not spent on adjusting parameters but on other operations in LSTM and GRU.

# %%
for units in [10, 100, 150, 200, 300]:
    print('[LSTM] units =', units, ':', rnn(lstm=True, units=units, epochs=3))
    print('[GRU] units =', units, ':', rnn(lstm=False, units=units, epochs=3))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 10)                5560
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 1,285,571
# Trainable params: 1,285,571
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.4344 - acc: 0.7977
# Epoch 2/3
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.2572 - acc: 0.8994
# Epoch 3/3
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.1789 - acc: 0.9333
# 25000/25000 [==============================] - 20s 815us/step
# 25000/25000 [==============================] - 20s 788us/step
# [LSTM] units = 10 : (0.96412, 0.85016)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_14 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# gru_1 (GRU)                  (None, 10)                4170
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 1,284,181
# Trainable params: 1,284,181
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 76s 3ms/step - loss: 0.4593 - acc: 0.7778
# Epoch 2/3
# 25000/25000 [==============================] - 74s 3ms/step - loss: 0.2709 - acc: 0.8916
# Epoch 3/3
# 25000/25000 [==============================] - 74s 3ms/step - loss: 0.1907 - acc: 0.9302
# 25000/25000 [==============================] - 17s 661us/step
# 25000/25000 [==============================] - 16s 640us/step
# [GRU] units = 10 : (0.96884, 0.84808)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_15 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 100)               91600
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 1,371,701
# Trainable params: 1,371,701
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.4169 - acc: 0.8050
# Epoch 2/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.2651 - acc: 0.8946
# Epoch 3/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.1903 - acc: 0.9248
# 25000/25000 [==============================] - 20s 810us/step
# 25000/25000 [==============================] - 20s 784us/step
# [LSTM] units = 100 : (0.96372, 0.83808)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_16 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# gru_2 (GRU)                  (None, 100)               68700
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 1,348,801
# Trainable params: 1,348,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 76s 3ms/step - loss: 0.4207 - acc: 0.8029
# Epoch 2/3
# 25000/25000 [==============================] - 75s 3ms/step - loss: 0.2491 - acc: 0.9004
# Epoch 3/3
# 25000/25000 [==============================] - 74s 3ms/step - loss: 0.1586 - acc: 0.9425
# 25000/25000 [==============================] - 17s 662us/step
# 25000/25000 [==============================] - 16s 635us/step
# [GRU] units = 100 : (0.97464, 0.84784)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_17 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.4379 - acc: 0.7898
# Epoch 2/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.2646 - acc: 0.8942
# Epoch 3/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.1829 - acc: 0.9304
# 25000/25000 [==============================] - 21s 829us/step
# 25000/25000 [==============================] - 20s 797us/step
# [LSTM] units = 150 : (0.94716, 0.8316)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_18 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# gru_3 (GRU)                  (None, 150)               125550
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,405,701
# Trainable params: 1,405,701
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 77s 3ms/step - loss: 0.4293 - acc: 0.7956
# Epoch 2/3
# 25000/25000 [==============================] - 75s 3ms/step - loss: 0.2573 - acc: 0.8972
# Epoch 3/3
# 25000/25000 [==============================] - 75s 3ms/step - loss: 0.1692 - acc: 0.9382
# 25000/25000 [==============================] - 17s 671us/step
# 25000/25000 [==============================] - 16s 649us/step
# [GRU] units = 150 : (0.96908, 0.84532)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_19 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 200)               263200
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 1,543,401
# Trainable params: 1,543,401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.4456 - acc: 0.7847
# Epoch 2/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.2755 - acc: 0.8884
# Epoch 3/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.1954 - acc: 0.9249
# 25000/25000 [==============================] - 21s 822us/step
# 25000/25000 [==============================] - 20s 790us/step
# [LSTM] units = 200 : (0.96444, 0.84276)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_20 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# gru_4 (GRU)                  (None, 200)               197400
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 1,477,601
# Trainable params: 1,477,601
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 77s 3ms/step - loss: 0.4273 - acc: 0.7975
# Epoch 2/3
# 25000/25000 [==============================] - 74s 3ms/step - loss: 0.2497 - acc: 0.8999
# Epoch 3/3
# 25000/25000 [==============================] - 74s 3ms/step - loss: 0.1601 - acc: 0.9406
# 25000/25000 [==============================] - 17s 669us/step
# 25000/25000 [==============================] - 16s 646us/step
# [GRU] units = 200 : (0.97884, 0.84848)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_21 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 300)               514800
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 301
# =================================================================
# Total params: 1,795,101
# Trainable params: 1,795,101
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 97s 4ms/step - loss: 0.4453 - acc: 0.7864
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2746 - acc: 0.8891
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.1866 - acc: 0.9292
# 25000/25000 [==============================] - 21s 853us/step
# 25000/25000 [==============================] - 21s 820us/step
# [LSTM] units = 300 : (0.95504, 0.83988)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_22 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# gru_5 (GRU)                  (None, 300)               386100
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 301
# =================================================================
# Total params: 1,666,401
# Trainable params: 1,666,401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 78s 3ms/step - loss: 0.4556 - acc: 0.7754
# Epoch 2/3
# 25000/25000 [==============================] - 75s 3ms/step - loss: 0.2690 - acc: 0.8902
# Epoch 3/3
# 25000/25000 [==============================] - 76s 3ms/step - loss: 0.1720 - acc: 0.9354
# 25000/25000 [==============================] - 17s 685us/step
# 25000/25000 [==============================] - 16s 648us/step
# [GRU] units = 300 : (0.97624, 0.8484)

# %% [markdown]
# 4. Loss function
#     - Results
#         * loss = mean_squared_error : (0.94068, 0.8322)
#         * loss = mean_absolute_error : (0.5716, 0.55848)
#         * loss = mean_absolute_percentage_error : (0.5, 0.5)
#         * loss = squared_hinge : (0.5, 0.5)
#         * loss = hinge : (0.5, 0.5)
#         * loss = categorical_hinge : (0.53876, 0.53044)
#         * loss = logcosh : (0.94376, 0.8356)
#         * loss = sparse_categorical_crossentropy : (0.0, 0.0)
#         * loss = binary_crossentropy : (0.96752, 0.84524)
#         * loss = kullback_leibler_divergence : (0.5, 0.5)
#         * loss = poisson : (0.94372, 0.83748)
#         * loss = cosine_proximity : (0.5, 0.5)
#     - Some loss functions are not appropriate for this problem, which lead to very low accuracy.
#     - Mean absolute percentage error is not appropriate for binary problems. The loss would be divided by the expected value and became infinite if the expected value is zero.
#     - Hinge and cosine proximity are also not made for binary problems. The expected value and predicted value would be multiplied, which did not provide any information if the expected value is zero.
#     - KL divergence requires multiplying the excepted value, which is always zero if the expected value is zero.
#     - Sparse categorical crossentropy is made for categorical problems and exception would be raised if it was applied on binary problems.
#     - Mean square error, logcosh, binary crossentropy and poissen fit this problem better and all gave pretty good results.

# %%
for loss in ['mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'squared_hinge', 'hinge', 'categorical_hinge', 'logcosh', 'sparse_categorical_crossentropy', 'binary_crossentropy', 'kullback_leibler_divergence', 'poisson', 'cosine_proximity']:
    print('loss =', loss, ':', rnn(loss=loss, epochs=3))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_23 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.1458 - acc: 0.7903
# Epoch 2/3
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.0839 - acc: 0.8889
# Epoch 3/3
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.0599 - acc: 0.9235
# 25000/25000 [==============================] - 21s 836us/step
# 25000/25000 [==============================] - 20s 791us/step
# loss = mean_squared_error : (0.94068, 0.8322)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_24 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.3948 - acc: 0.6127
# Epoch 2/3
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.4292 - acc: 0.5708
# Epoch 3/3
# 25000/25000 [==============================] - 93s 4ms/step - loss: 0.4290 - acc: 0.5710
# 25000/25000 [==============================] - 21s 837us/step
# 25000/25000 [==============================] - 20s 804us/step
# loss = mean_absolute_error : (0.5716, 0.55848)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_25 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 97s 4ms/step - loss: 3051325.8888 - acc: 0.5001
# Epoch 2/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 301.8693 - acc: 0.5000
# Epoch 3/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 191.1322 - acc: 0.5000
# 25000/25000 [==============================] - 21s 841us/step
# 25000/25000 [==============================] - 20s 798us/step
# loss = mean_absolute_percentage_error : (0.5, 0.5)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_26 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 97s 4ms/step - loss: 0.5014 - acc: 0.5001
# Epoch 2/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.5000 - acc: 0.5000
# Epoch 3/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.5000 - acc: 0.5000
# 25000/25000 [==============================] - 21s 845us/step
# 25000/25000 [==============================] - 20s 804us/step
# loss = squared_hinge : (0.5, 0.5)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_27 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 98s 4ms/step - loss: 0.5026 - acc: 0.5002
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.5000 - acc: 0.5000
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.5000 - acc: 0.5000
# 25000/25000 [==============================] - 21s 845us/step
# 25000/25000 [==============================] - 20s 805us/step
# loss = hinge : (0.5, 0.5)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_28 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 98s 4ms/step - loss: 0.9675 - acc: 0.5346
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.9621 - acc: 0.5379
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.9616 - acc: 0.5384
# 25000/25000 [==============================] - 21s 848us/step
# 25000/25000 [==============================] - 20s 809us/step
# loss = categorical_hinge : (0.53876, 0.53044)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_29 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_24 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 98s 4ms/step - loss: 0.0704 - acc: 0.7824
# Epoch 2/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0405 - acc: 0.8828
# Epoch 3/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.0299 - acc: 0.9168
# 25000/25000 [==============================] - 21s 843us/step
# 25000/25000 [==============================] - 20s 803us/step
# loss = logcosh : (0.94376, 0.8356)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_30 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 97s 4ms/step - loss: nan - acc: 4.8000e-04
# Epoch 2/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: nan - acc: 0.0000e+00
# Epoch 3/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: nan - acc: 0.0000e+00
# 25000/25000 [==============================] - 21s 849us/step
# 25000/25000 [==============================] - 20s 806us/step
# loss = sparse_categorical_crossentropy : (0.0, 0.0)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_31 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 99s 4ms/step - loss: 0.4326 - acc: 0.7944
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2639 - acc: 0.8927
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.1857 - acc: 0.9284
# 25000/25000 [==============================] - 21s 854us/step
# 25000/25000 [==============================] - 20s 807us/step
# loss = binary_crossentropy : (0.96752, 0.84524)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_32 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 98s 4ms/step - loss: 0.0038 - acc: 0.5004
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: -5.7930e-07 - acc: 0.5000
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: -6.7942e-07 - acc: 0.5000
# 25000/25000 [==============================] - 21s 859us/step
# 25000/25000 [==============================] - 20s 807us/step
# loss = kullback_leibler_divergence : (0.5, 0.5)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_33 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_28 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_33 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 98s 4ms/step - loss: 0.7223 - acc: 0.7885
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.6409 - acc: 0.8822
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.6049 - acc: 0.9111
# 25000/25000 [==============================] - 22s 860us/step
# 25000/25000 [==============================] - 20s 806us/step
# loss = poisson : (0.94372, 0.83748)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_34 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_29 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 98s 4ms/step - loss: -0.5000 - acc: 0.5002
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: -0.5000 - acc: 0.5000
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: -0.5000 - acc: 0.5000
# 25000/25000 [==============================] - 22s 868us/step
# 25000/25000 [==============================] - 20s 815us/step
# loss = cosine_proximity : (0.5, 0.5)

# %% [markdown]
# 5. Optimizer
#     - Results
#         * optimizer = sgd : (0.53596, 0.5262)
#         * optimizer = rmsprop : (0.91224, 0.84604)
#         * optimizer = adagrad : (0.94904, 0.85024)
#         * optimizer = adadelta : (0.871, 0.83224)
#         * optimizer = adam : (0.96532, 0.84416)
#         * optimizer = adamax : (0.92492, 0.84612)
#         * optimizer = nadam : (0.96584, 0.84236)

# %%
for optimizer in ['sgd', 'rmsprop', 'adagrad', 'adadelta', 'adam', 'adamax', 'nadam']:
    print('optimizer =', optimizer, ':', rnn(optimizer=optimizer, epochs=3))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_35 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_30 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 97s 4ms/step - loss: 0.6933 - acc: 0.4981
# Epoch 2/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.6931 - acc: 0.5033
# Epoch 3/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.6929 - acc: 0.5133
# 25000/25000 [==============================] - 22s 863us/step
# 25000/25000 [==============================] - 20s 810us/step
# optimizer = sgd : (0.53596, 0.5262)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_36 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_31 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 98s 4ms/step - loss: 0.4346 - acc: 0.8008
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2992 - acc: 0.8789
# Epoch 3/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.2558 - acc: 0.8984
# 25000/25000 [==============================] - 21s 859us/step
# 25000/25000 [==============================] - 20s 810us/step
# optimizer = rmsprop : (0.91224, 0.84604)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_37 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_37 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 98s 4ms/step - loss: 0.4298 - acc: 0.7990
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2578 - acc: 0.8960
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.1982 - acc: 0.9261
# 25000/25000 [==============================] - 22s 868us/step
# 25000/25000 [==============================] - 20s 813us/step
# optimizer = adagrad : (0.94904, 0.85024)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_38 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_33 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 100s 4ms/step - loss: 0.5614 - acc: 0.6893
# Epoch 2/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.3711 - acc: 0.8412
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.3169 - acc: 0.8686
# 25000/25000 [==============================] - 22s 872us/step
# 25000/25000 [==============================] - 21s 831us/step
# optimizer = adadelta : (0.871, 0.83224)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_39 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_34 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 100s 4ms/step - loss: 0.4208 - acc: 0.8016
# Epoch 2/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.2695 - acc: 0.8918
# Epoch 3/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.1947 - acc: 0.9257
# 25000/25000 [==============================] - 22s 872us/step
# 25000/25000 [==============================] - 21s 830us/step
# optimizer = adam : (0.96532, 0.84416)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_40 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_35 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_40 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 99s 4ms/step - loss: 0.4205 - acc: 0.8050
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2944 - acc: 0.8787
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2475 - acc: 0.9017
# 25000/25000 [==============================] - 22s 890us/step
# 25000/25000 [==============================] - 21s 823us/step
# optimizer = adamax : (0.92492, 0.84612)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_41 (Embedding)     (None, None, 128)         1280000
# _________________________________________________________________
# lstm_36 (LSTM)               (None, 150)               167400
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 1,447,551
# Trainable params: 1,447,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 100s 4ms/step - loss: 0.4550 - acc: 0.7830
# Epoch 2/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.2718 - acc: 0.8882
# Epoch 3/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.1753 - acc: 0.9346
# 25000/25000 [==============================] - 22s 883us/step
# 25000/25000 [==============================] - 21s 828us/step
# optimizer = nadam : (0.96584, 0.84236)

# %% [markdown]
# 6. Embedding dimensions
#     - Results
#         * embedding dimension = 10 , units = 100 : (0.92968, 0.84184)
#         * embedding dimension = 50 , units = 100 : (0.96032, 0.84184)
#         * embedding dimension = 100 , units = 100 : (0.9582, 0.84036)
#         * embedding dimension = 100 , units = 50 : (0.941, 0.82712)
#         * embedding dimension = 100 , units = 10 : (0.9686, 0.84416)
#     - According to the previous experiments, the number of units does not obviously affect the results.
#     - As shown, the number of embedding dimension does not obviously affect the results as well. The preserved information seems to be enough even when the embedding dimension was only 10.

# %%
for embed_dim, units in [(10, 100), (50, 100), (100, 100), (100, 50), (100, 10)]:
    print('embedding dimension =', embed_dim, ', units =', units, ':', rnn(embed_dim=embed_dim, units=units, epochs=3))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_42 (Embedding)     (None, None, 10)          100000
# _________________________________________________________________
# lstm_37 (LSTM)               (None, 100)               44400
# _________________________________________________________________
# dense_42 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 144,501
# Trainable params: 144,501
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 99s 4ms/step - loss: 0.4714 - acc: 0.7640
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2896 - acc: 0.8825
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2380 - acc: 0.9088
# 25000/25000 [==============================] - 22s 872us/step
# 25000/25000 [==============================] - 20s 816us/step
# embedding dimension = 10 , units = 100 : (0.92968, 0.84184)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_43 (Embedding)     (None, None, 50)          500000
# _________________________________________________________________
# lstm_38 (LSTM)               (None, 100)               60400
# _________________________________________________________________
# dense_43 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 560,501
# Trainable params: 560,501
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 99s 4ms/step - loss: 0.4283 - acc: 0.7939
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2799 - acc: 0.8852
# Epoch 3/3
# 25000/25000 [==============================] - 94s 4ms/step - loss: 0.2075 - acc: 0.9195
# 25000/25000 [==============================] - 22s 876us/step
# 25000/25000 [==============================] - 20s 808us/step
# embedding dimension = 50 , units = 100 : (0.96032, 0.84184)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_44 (Embedding)     (None, None, 100)         1000000
# _________________________________________________________________
# lstm_39 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 1,080,501
# Trainable params: 1,080,501
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 100s 4ms/step - loss: 0.4240 - acc: 0.7978
# Epoch 2/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.2662 - acc: 0.8940
# Epoch 3/3
# 25000/25000 [==============================] - 96s 4ms/step - loss: 0.1974 - acc: 0.9229
# 25000/25000 [==============================] - 22s 879us/step
# 25000/25000 [==============================] - 20s 808us/step
# embedding dimension = 100 , units = 100 : (0.9582, 0.84036)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_45 (Embedding)     (None, None, 100)         1000000
# _________________________________________________________________
# lstm_40 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dense_45 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 1,030,251
# Trainable params: 1,030,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 99s 4ms/step - loss: 0.4126 - acc: 0.8046
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2548 - acc: 0.8969
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.1828 - acc: 0.9289
# 25000/25000 [==============================] - 22s 888us/step
# 25000/25000 [==============================] - 21s 825us/step
# embedding dimension = 100 , units = 50 : (0.941, 0.82712)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_46 (Embedding)     (None, None, 100)         1000000
# _________________________________________________________________
# lstm_41 (LSTM)               (None, 10)                4440
# _________________________________________________________________
# dense_46 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 1,004,451
# Trainable params: 1,004,451
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 100s 4ms/step - loss: 0.4374 - acc: 0.7965
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.2593 - acc: 0.8980
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 0.1771 - acc: 0.9355
# 25000/25000 [==============================] - 22s 899us/step
# 25000/25000 [==============================] - 21s 823us/step
# embedding dimension = 100 , units = 10 : (0.9686, 0.84416)
